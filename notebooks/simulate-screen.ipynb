# %%
import tfscreen
tfscreen.run_simulation(yaml_file="input.yaml",
                        output_prefix="test",
                        output_path="output")
# Out:
# loading configuration 'input.yaml':   0%|                                                                     …
# generating library sequences:   0%|                                                                           …
# setting up conditions:   0%|                                                                                  …
# calculating phenotypes:   0%|                                                                                 …
# simulating transformation:   0%|                                                                              …
# initializing sample:   0%|                                                                                    …
# getting initial populations:   0%|                                                                            …
# growing populations:   0%|                                                                                    …
# ...

# %%
import pandas as pd
combined_df = pd.read_csv("output/yo-combined_df.csv")
combined_df
# Out:
#            genotype  genotype_number            timepoint           sample  \
# 0                wt                0   77|kanR|0|1e-06|80  77|kanR|0|1e-06
# 1                wt                0   77|kanR|0|1e-06|95  77|kanR|0|1e-06
# 2                wt                0  77|kanR|0|1e-06|110  77|kanR|0|1e-06
# 3                wt                0     77|kanR|0|1.0|80    77|kanR|0|1.0
# 4                wt                0     77|kanR|0|1.0|95    77|kanR|0|1.0
# ...             ...              ...                  ...              ...
# 13493395  K59Y/M98Y           224889    77|pheS|1|0.1|110    77|pheS|1|0.1
# 13493396  K59Y/M98Y           224889    77|pheS|1|0.1|125    77|pheS|1|0.1
# 13493397  K59Y/M98Y           224889     77|pheS|1|1.0|95    77|pheS|1|1.0
# 13493398  K59Y/M98Y           224889    77|pheS|1|1.0|110    77|pheS|1|1.0
# 13493399  K59Y/M98Y           224889    77|pheS|1|1.0|125    77|pheS|1|1.0
#
#           sample_number  time  counts  total_cfu_mL_at_time  \
# ...

# %%
sample_df = pd.read_csv("output/yo-sample_df.csv")
sample_df
# Out:
#           Unnamed: 0  replicate marker  select      iptg
# 0    77|kanR|0|1e-06         77   kanR       0  0.000001
# 1      77|kanR|0|1.0         77   kanR       0  1.000000
# 2    77|kanR|1|1e-06         77   kanR       1  0.000001
# 3   77|kanR|1|0.0001         77   kanR       1  0.000100
# 4    77|kanR|1|0.001         77   kanR       1  0.001000
# 5    77|kanR|1|0.003         77   kanR       1  0.003000
# 6     77|kanR|1|0.01         77   kanR       1  0.010000
# 7     77|kanR|1|0.03         77   kanR       1  0.030000
# 8      77|kanR|1|0.1         77   kanR       1  0.100000
# 9      77|kanR|1|1.0         77   kanR       1  1.000000
# 10   77|pheS|0|1e-06         77   pheS       0  0.000001
# 11     77|pheS|0|1.0         77   pheS       0  1.000000
# 12   77|pheS|1|1e-06         77   pheS       1  0.000001
# 13  77|pheS|1|0.0001         77   pheS       1  0.000100
# 14   77|pheS|1|0.001         77   pheS       1  0.001000
# ...

# %%
phenotype_df = pd.read_csv("output/yo-phenotype_df.csv")
phenotype_df
# Out:
#           genotype marker  select      iptg  fx_occupied  fx_folded       obs  \
# 0               wt   kanR       0  0.000001     0.000987        1.0  0.011846
# 1               wt   kanR       0  1.000000     0.038626        1.0  0.463514
# 2               wt   kanR       1  0.000001     0.000987        1.0  0.011846
# 3               wt   kanR       1  0.000100     0.000990        1.0  0.011880
# 4               wt   kanR       1  0.001000     0.001016        1.0  0.012191
# ...            ...    ...     ...       ...          ...        ...       ...
# 4497795  K59Y/M98Y   pheS       1  0.003000     0.001963        1.0  0.023551
# 4497796  K59Y/M98Y   pheS       1  0.010000     0.002582        1.0  0.030989
# 4497797  K59Y/M98Y   pheS       1  0.030000     0.004397        1.0  0.052764
# 4497798  K59Y/M98Y   pheS       1  0.100000     0.010766        1.0  0.129195
# 4497799  K59Y/M98Y   pheS       1  1.000000     0.040696        1.0  0.488354
#
# ...
